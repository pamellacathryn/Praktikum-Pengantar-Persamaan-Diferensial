# %% [markdown]
# **PRAKTIKUM KE-1**

# %% [markdown]
#  * Nama : Pamella Cathryn
#  * NIM  : 10820033
#  * Asisten : Maria Kirana

# %% [markdown]
# ![messageImage_1643957731755.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **NO.1** (Type your description here!)

# %%
import numpy as np

#a.
print("a.")
A = np.array([[1,1,1],[1,0,1],[1,1,1]])
B = np.array([[1,2,3],[1,1,1],[6,5,4]])
print("A =",A)
print("B =",B)
print()

#b
print("b.")
C = np.matmul(A,B)
print("C =",C)
print()

#c
print("c.")
eigvals, eigvecs = np.linalg.eig(C)
print("nilai eigen =", eigvals)
print("vektor eigen =",eigvecs)
print('''
Penjelasan: C memiliki
vektor eigen [ 0.60131682 -0.21406973  0.43932882] yang berkorespondesi dengan nilai eigen 2.30000000e+01
vektor eigen [ 0.52615222 -0.57533645 -0.81568676] yang berkorespondesi dengan nilai eigen 1.28994202e-16
vektor eigen [ 0.60131682  0.78940618  0.37635794] yang berkorespondesi dengan nilai eigen -1.00116009e-15
''')
# Out:
# a.
# A = [[1 1 1]
#  [1 0 1]
#  [1 1 1]]
# B = [[1 2 3]
#  [1 1 1]
#  [6 5 4]]
#
# b.
# C = [[8 8 8]
#  [7 7 7]
#  [8 8 8]]
#
# c.
# nilai eigen = [ 2.30000000e+01  1.28994202e-16 -1.00116009e-15]
# vektor eigen = [[ 0.60131682 -0.21406973  0.43932882]
#  [ 0.52615222 -0.57533645 -0.81568676]
#  [ 0.60131682  0.78940618  0.37635794]]
#
# Penjelasan: C memiliki
# vektor eigen [ 0.60131682 -0.21406973  0.43932882] yang berkorespondesi dengan nilai eigen 2.30000000e+01
# vektor eigen [ 0.52615222 -0.57533645 -0.81568676] yang berkorespondesi dengan nilai eigen 1.28994202e-16
# vektor eigen [ 0.60131682  0.78940618  0.37635794] yang berkorespondesi dengan nilai eigen -1.00116009e-15

# %% [markdown]
# **NO.2** (Type your description here!)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

def f(x,i): #definisikan fungsi untuk memuat x dan i
  sum=0
  t=1 #mulai dari 1
  while True:
    sum+=(1/t)*np.sin(t*math.pi*x/2) #fungsi dalam sigma
    if t+2>i:
      break
    t+=2 #1,3,5,...,i melongkap 2
  return 4*sum/math.pi #hasil perhitungan sigma kalikan dengan 4/pi

array_i=[1,3,5,7,9] #array untuk i
array_x=np.linspace(-2*math.pi, 2*math.pi, 400) #array untuk x

for i in array_i:
  dots=[]
  for x in list_x:
    dots.append(f(x,i))
  plt.plot(dots)

plt.legend(['i=1', 'i=3', 'i=5', 'i=7', 'i=9'])
plt.show()

print('''Semakin besar nilai i, 
maka semakin banyak perubahan nilai/perubahan arah gerak kurva di daerah titik ekstrem sumbu.
Juga dapat melihat bahwa penambahan nilai i akan menambah jumlah titik ekstrem,seperti titik ekstrem minor.''')
# Out:
# Dari grafik, kita dapat melihat bahwa semakin besar nilai i,
# maka semakin banyak perubahan nilai/perubahan arah gerak kurva di daerah titik ekstrem sumbu. kita juga dapat melihat
# bahwa penambahan nilai i akan menambah jumlah titik ekstrem,seperti titik ekstrem minor.

# %% [markdown]
# **NO.3** (Type your description here!)

# %%
from sympy import Function, dsolve, solve, Derivative, symbols
from sympy.abc import x
y = Function('y')

sol = dsolve(Derivative(y(x), x) + (y(x)/x)*((2*x**3-(y(x))**3)/(2*(y(x))**3-x**3)), y(x)).rhs
constants = solve([sol.subs(x,1)-1])
jawaban_akhir = sol.subs(constants)
print("solusi umum =",sol)
print("solusi khusus =",jawaban_akhir)
# Out:
# solusi umum = C1*x
# solusi khusus = x

# %% [markdown]
# The code ends here
